# %%
import numpy as np

# %%
dat=np.load('//ZMN-HIVE/User-Data/Maria/segmented/fish44_6dpf_amph_raw_traces.npy')

# %%
print(dat.shape)
# Out:
# (21522, 1800)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dat[1600,:])

# %%
# !python -m pip install ruptures
# Out:
# Collecting ruptures
#   Downloading ruptures-1.1.2-cp38-cp38-win_amd64.whl (179 kB)
# Requirement already satisfied: scipy in c:\users\koester_lab\anaconda3\lib\site-packages (from ruptures) (1.5.0)
# Requirement already satisfied: numpy in c:\users\koester_lab\anaconda3\lib\site-packages (from ruptures) (1.18.5)
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.2

# %%
import ruptures as rpt
signal=dat[1600,:]
algo = rpt.Pelt(model="rbf").fit(signal)
result = algo.predict(pen=10)

# %%
print(result)
# Out:
# [205, 295, 350, 655, 955, 1215, 1430, 1800]

# %%
plt.plot(signal)
plt.axvline(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6c1dccf49fe2> in <module>
#       1 plt.plot(signal)
# ----> 2 plt.axvline(result)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in axvline(x, ymin, ymax, **kwargs)
#    2391 @docstring.copy(Axes.axvline)
#    2392 def axvline(x=0, ymin=0, ymax=1, **kwargs):
# -> 2393     return gca().axvline(x=x, ymin=ymin, ymax=ymax, **kwargs)
#    2394
#    2395
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in axvline(self, x, ymin, ymax, **kwargs)
#     914         self._process_unit_info(xdata=x, kwargs=kwargs)
#     915         xx = self.convert_xunits(x)
# --> 916         scalex = (xx < xmin) or (xx > xmax)
#     917
#     918         trans = self.get_xaxis_transform(which='grid')
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
